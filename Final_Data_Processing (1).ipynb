# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %%
# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read the dataset from the specified path
df = pd.read_csv('/content/drive/MyDrive/ML project/fake_real.csv', sep=',', encoding='utf-8', quotechar='"')
# Display the first few rows of the DataFrame
df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  type
# 0  December 31, 2017   True
# 1  December 29, 2017   True
# 2  December 31, 2017   True
# 3  December 30, 2017   True
# 4  December 29, 2017   True

# %%
# Display the last few rows of the DataFrame
df.tail()
# Out:
#                                                    title  \
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 44893  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 44894  21st Century Wire says It s a familiar theme. ...  Middle-east
# 44895  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 44896  21st Century Wire says Al Jazeera America will...  Middle-east
# 44897  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date  type
# 44893  January 16, 2016  Fake
# 44894  January 16, 2016  Fake
# 44895  January 15, 2016  Fake
# 44896  January 14, 2016  Fake
# 44897  January 12, 2016  Fake

# %%
# Function to remove 'Reuter' and 'Reuters' including adjacent special characters
def remove_reuter(text):
    return re.sub(r"\s*\(Reuters\)\s*", "", text)

# Apply the function to the 'text' column
df['text'] = df['text'].apply(remove_reuter)

# Display the modified DataFrame
df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON- The head of a conservative Republi...  politicsNews
# 1  WASHINGTON- Transgender people will be allowed...  politicsNews
# 2  WASHINGTON- The special counsel investigation ...  politicsNews
# 3  WASHINGTON- Trump campaign adviser George Papa...  politicsNews
# 4  SEATTLE/WASHINGTON- President Donald Trump cal...  politicsNews
#
#                  date  type
# 0  December 31, 2017   True
# 1  December 29, 2017   True
# 2  December 31, 2017   True
# 3  December 30, 2017   True
# 4  December 29, 2017   True

# %%
# Save DataFrame to a CSV file
df.to_csv('fake_real.csv', index=False)

# %%
# Create a download link
from IPython.display import FileLink
FileLink('fake_real.csv')
# Out:
# /content/fake_real.csv
